# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import cv2
img = cv2.imread('data/p1.jpg')
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img)
plt.show()

# %%
sobely = cv2.Sobel(gray_img,cv2.CV_64F,0,1,ksize=5)

# %%
sum_rows=sobely.sum(axis=1)

# %%
max_index=sum_rows.argmax(axis=0)

# %%
import heapq
temp=heapq.nlargest(150, range(len(sum_rows)), sum_rows.take)

# %%
threshold=40

# %%
final_img=sobely[max_index-threshold:max_index+threshold]
final_img
# Out:
# array([[  426.,   422.,   398., ...,   300.,   112.,     0.],
#        [   70.,    77.,    87., ...,   206.,   145.,   112.],
#        [ -330.,  -297.,  -226., ...,    67.,   174.,   248.],
#        ...,
#        [  122.,   128.,   123., ..., -1271.,  -953.,  -774.],
#        [  156.,   174.,   168., ...,  -860.,  -581.,  -416.],
#        [   66.,    71.,    35., ...,  -548.,  -602.,  -612.]])

# %%
plt.imshow(final_img)
plt.show()

# %%
img2 = cv2.imread('p4.jpg')
gray_img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
# Out:
# [ WARN:0@146.919] global /croot/opencv-suite_1676452025216/work/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('p4.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[19], line 2
#       1 img2=cv2.imread('p4.jpg')
# ----> 2 gray_img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
#
# error: OpenCV(4.6.0) /croot/opencv-suite_1676452025216/work/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
