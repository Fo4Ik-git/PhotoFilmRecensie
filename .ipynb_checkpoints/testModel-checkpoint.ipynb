# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import cv2
img = cv2.imread('data/p1.jpg')
gray_img = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
plt.imshow(img)
plt.show()
sobely = cv2.Sobel(gray_img,cv2.CV_64F,0,1,ksize=5)
sum_rows=sobely.sum(axis=1)
max_index=sum_rows.argmax(axis=0)

import heapq
temp=heapq.nlargest(150, range(len(sum_rows)), sum_rows.take)

threshold=40
final_img=sobely[max_index-threshold:max_index+threshold]
final_img

plt.imshow(final_img)
plt.show()

# %%
img = cv2.imread('data/p4.jpg')
gray_img = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
plt.imshow(img)
plt.show()
sobely = cv2.Sobel(gray_img,cv2.CV_64F,0,1,ksize=5)
sum_rows=sobely.sum(axis=1)
max_index=sum_rows.argmax(axis=0)

import heapq
temp=heapq.nlargest(150, range(len(sum_rows)), sum_rows.take)

threshold=40
final_img=sobely[max_index-threshold:max_index+threshold]
final_img

plt.imshow(final_img)
plt.show()

# %%
img = cv2.imread('data/p5.jpg')
gray_img = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
plt.imshow(img)
plt.show()
sobely = cv2.Sobel(gray_img,cv2.CV_64F,0,1,ksize=5)
sum_rows=sobely.sum(axis=1)
max_index=sum_rows.argmax(axis=0)

import heapq
temp=heapq.nlargest(150, range(len(sum_rows)), sum_rows.take)

threshold=40
final_img=sobely[max_index-threshold:max_index+threshold]
final_img

plt.imshow(final_img)
plt.show()

# %%
img = cv2.imread('data/p6.jpg')
gray_img = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
plt.imshow(img)
plt.show()
sobely = cv2.Sobel(gray_img,cv2.CV_64F,0,1,ksize=5)
sum_rows=sobely.sum(axis=1)
max_index=sum_rows.argmax(axis=0)

import heapq
temp=heapq.nlargest(150, range(len(sum_rows)), sum_rows.take)

threshold=40
final_img=sobely[max_index-threshold:max_index+threshold]
final_img

plt.imshow(final_img)
plt.show()
